# %% [markdown]
# # Blender-vs-CT decomposition gap — systematic investigation
#
# *(Notebook generated by Claude, 2026-07-02. All experiments run on the same data used by `3dfront_ct.ipynb`.)*
#
# **Problem.** Decomposing the **CT-SH-rendered** dataset (`results/3dfront-dataset-sh`) works well
# (roughness RMSE → ~0.1, albedo scale ≈ 1), but decomposing the **Blender-rendered** dataset
# (`results/3dfront-dataset-env[...]`, rendered from the *same* SH lights) gives much higher loss,
# poor intrinsics, and albedo scale drifting far from 1.
# **User hypothesis:** numerical issues at low roughness despite EXR + float64.
#
# ## Pipeline recap (from reading the code)
#
# Both datasets use the **same 128 SH lights** from `results/ref_sh_lighting/sh_iii.npy`
# (already normalized so the rectified env-map peak = 1). For light *i*:
#
# | | CT dataset (`3dfront-dataset-sh`) | Blender dataset (`E:\...\1\env_i.*`) |
# |---|---|---|
# | geometry | proxy: camera (0,0,2), fragments on z=0 plane, fov 60° | real 3-D scene, real camera |
# | lighting input | **signed** SH coefficients (9,3), directly | `sh_env_map_i.png` = **rectified** (`max(·,0)`), max-normalized, **8-bit** 64×32 env map, camera-locked, × strength **2.0** |
# | shading | `shade_ct_sh`: order-2 SH irradiance + GGX-SH-LUT specular, `F·G1(view)/4` | Cycles path tracing, Principled BSDF, `max_bounces=0` (direct only), mesh shadows disabled, 512 spp |
# | storage | float32 `.npy` (lossless) + 8-bit PNG | EXR (linear float) + linear 8-bit PNG (clipped [0,1], **truncating** quantization) |
#
# The decomposition (`decompose_scene` → `_optimize_ct_sh`) runs L-BFGS over per-pixel albedo,
# sigmoid-transformed metallic/roughness maps and one 9×3 SH per image, with L2 + TV + metallic-binarize loss.
# The wandb run names show the plotted "Blender" run used `3dfront-dataset-env` (no `_npy` tag ⇒
# **8-bit linear PNGs, clipped**), while the "CT" run used lossless `.npy`.
#
# > ⚠ Side finding from code reading: `_fwd_albedo` only implements the `"log"` transform —
# > `tr_albedo="sigmoid"` is silently a **no-op** (albedo is optimized unconstrained/identity).
#
# ## Hypotheses
#
# - **H1 (user):** numerical precision breaks at low roughness (float32 vs float64).
# - **H2:** input quantization/clipping (8-bit PNG images, 8-bit env map, truncation).
# - **H3:** lighting-representation mismatch — Blender is lit by the *rectified* env map;
#   the CT-SH model can only represent *signed order-2 SH* lighting. Rectification creates
#   higher-band content the model cannot express (worst for sharp/low-roughness speculars).
# - **H4:** BSDF mismatch — Cycles Principled (multiscatter GGX, full Smith G, exact env integration)
#   vs the CT approximation (SH-filtered specular, view-only G1, split-sum-style `F·G1·L/4`).
# - **H5:** geometry mismatch — proxy plane/fov-60 view directions vs the real perspective.
#
# ## Experiments
#
# - **E0** data audit: paired stats CT vs Blender-EXR vs Blender-PNG
# - **E1** forward-model consistency: render with **GT intrinsics + GT lighting**, compare to Blender
# - **E2** residual structure vs GT roughness / metallic
# - **E3** numerics: float32 vs float64 forward passes; quantization floors
# - **E4** best-achievable lighting-only fit (GT intrinsics fixed, only SH optimized)
# - **E5** decomposition attribution: control (CT), full (Blender), frozen-GT-lighting (Blender)
# - **E6** root-cause hunt via controlled Blender renders (minimal repro + verified fix)
#
# A conclusions section at the bottom summarizes what was found.

# %%
import os
import sys, json, time
from pathlib import Path
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# Repo root, found by walking up from the CWD. Notebooks live in notebooks/, but the
# code and the relative data paths below are relative to the repo root, so chdir there.
REPO = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "idr").is_dir())
os.chdir(REPO)
if str(REPO) not in sys.path:
    sys.path.insert(0, str(REPO))

from idr.data.geometry import make_proxy_geometry
from idr.data.scene_io import load_scene, load_exr
from idr.config import DEFAULT_CFG
from idr.optim.models.ct_sh import _optimize_ct_sh
from idr.eval.metrics import _albedo_rmse
from idr.render import shade_ct_sh, shade_ct_env, EnvMap
from idr.render import build_sh_basis
from idr.render.brdf import _get_ggx_sh_lut

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(0)
pd.set_option('display.width', 200); pd.set_option('display.float_format', lambda v: f'{v:.4f}')

BL_SRC     = Path(r'E:\3D-Front\output\backup 260703\00004f89-9aa5-43c2-ae3c-129586be8aaa\1')  # ORIGINAL (buggy) renders; the fixed re-render lives at E:\3D-Front\output\...
CT_DS      = Path('results/3dfront-dataset-sh')       # CT-SH-rendered dataset (same 128 SH lights)
ENV_EXR_DS = Path('results/3dfront-dataset-env_exr')  # Blender EXR/exr_scale as .npy
REF_SH     = Path('results/ref_lighting/dclift')          # the 128 SH lights + their env-map PNGs

ENV_STRENGTH = 2.0   # BlenderProc env_map_strength used for env_* renders
EXR_SCALE = json.load(open(ENV_EXR_DS / 'config.json'))['exr_scale']
N_CMP = 16           # paired lights used in the forward-model comparisons

# ---- GT maps + CT-rendered images + SH coefficients -------------------------
scene = load_scene(CT_DS, use_npy=True)
H, W      = scene['H'], scene['W']
mask_np   = scene['mask_np']
gt_albedo = scene['albedo_np']
gt_rough  = scene['roughness_np']
gt_metal  = scene['metallic_np']

sh_gt   = [np.load(REF_SH / f'sh_{i:03d}.npy').astype(np.float64) for i in range(128)]
env_png = [np.array(Image.open(REF_SH / f'sh_env_map_{i:03d}.png'), np.float64)[:, :, :3] / 255.0
           for i in range(128)]
ct_imgs = scene['images']                                                # lossless CT renders (npy)
bl_exr  = [load_exr(BL_SRC / f'env_{i}.exr').astype(np.float64) for i in range(N_CMP)]
bl_png  = [np.array(Image.open(BL_SRC / f'env_{i}.png'), np.float64)[:, :, :3] / 255.0
           for i in range(N_CMP)]

# ---- proxy geometry, float64 (same as decompose_scene(double=True)) ---------
normals_hw, frag_pos_hw, mask_hw, cam_pos = make_proxy_geometry(
    scene['normals_np'], mask_np, device=DEVICE, dtype=torch.float64)
flat_mask = mask_hw.reshape(-1)
mask_flat_np = mask_np.reshape(-1)
M = int(mask_flat_np.sum())

# cached per-dtype tensor sets so every forward test can run in f32 or f64
_tensor_cache = {}
def T(dtype=torch.float64):
    if dtype not in _tensor_cache:
        n_hw, f_hw, m_hw, c = make_proxy_geometry(
            scene['normals_np'], mask_np, device=DEVICE, dtype=dtype)
        fm = m_hw.reshape(-1)
        nm = n_hw.reshape(-1, 3)[fm]
        vm = torch.nn.functional.normalize(c.unsqueeze(0) - f_hw.reshape(-1, 3)[fm], dim=-1)
        def fl(arr):
            t = torch.from_numpy(np.ascontiguousarray(arr)).to(DEVICE, dtype)
            return t.reshape(-1, t.shape[-1])[fm]
        _tensor_cache[dtype] = dict(N=nm, V=vm, ab=fl(gt_albedo), ro=fl(gt_rough),
                                    me=fl(gt_metal), lut=_get_ggx_sh_lut(DEVICE).to(dtype))
    return _tensor_cache[dtype]

# ---- helpers -----------------------------------------------------------------
def scatter(flat_t):
    out = np.zeros((H * W, 3))
    out[mask_flat_np] = flat_t.detach().double().cpu().numpy()
    return out.reshape(H, W, 3)

def masked(img):
    return np.asarray(img, np.float64).reshape(-1, 3)[mask_flat_np]

def rmse(a, b):
    return float(np.sqrt(np.mean((masked(a) - masked(b)) ** 2)))

def opt_scale_rmse(model, target):
    '''Per-channel LS scale s minimizing ||s*model - target||, and the RMSE after scaling.'''
    m, t = masked(model), masked(target)
    s = (t * m).sum(0) / np.maximum((m * m).sum(0), 1e-12)
    return s, float(np.sqrt(np.mean((m * s - t) ** 2)))

def pearson(a, b):
    return float(np.corrcoef(masked(a).ravel(), masked(b).ravel())[0, 1])

print(f'device={DEVICE}  |  {H}x{W}, {M} masked px  |  exr_scale={EXR_SCALE:.4f}')
print(f'GT roughness mean={gt_rough[mask_np].mean():.3f}  GT metallic mean={gt_metal[mask_np].mean():.3f}')
# Out:
# device=cuda  |  124x124, 15376 masked px  |  exr_scale=0.4627
# GT roughness mean=0.248  GT metallic mean=0.062

# %% [markdown]
# ## E0 — Data audit
#
# Paired statistics for the first 16 lights. `light_i` (CT `.npy`, lossless) vs `env_i.exr`
# (Blender, lossless) vs `env_i.png` (Blender, 8-bit clipped — **this is what the plotted
# `3dfront-dataset-env` run consumed**).
#
# If the two renderers implemented the same forward model, `env_i ≈ 2.0 × light_i`
# (the Blender background strength). Things to look for:
# - is the ratio a constant 2.0, or does it vary per light? (varying ⇒ real model mismatch)
# - how much energy does the linear PNG lose to clipping (>1.0) and quantization?

# %%
rows = []
for i in range(N_CMP):
    ct, bl, blp = np.asarray(ct_imgs[i], np.float64), bl_exr[i], bl_png[i]
    s, sr = opt_scale_rmse(ct, bl)
    rows.append(dict(
        light=i,
        ct_mean=masked(ct).mean(),
        bl_mean=masked(bl).mean(),
        mean_ratio_bl_ct=masked(bl).mean() / masked(ct).mean(),
        ls_scale_ct_to_bl=s.mean(),
        rmse_bl_vs_scaled_ct=sr,
        corr_ct_bl=pearson(ct, bl),
        bl_px_over_1_pct=100.0 * (masked(bl) > 1.0).mean(),
        png_vs_exr_rmse=rmse(blp, np.clip(bl, 0, 1)),
    ))
df0 = pd.DataFrame(rows).set_index('light')
print(df0.to_string())
print('\nSummary: expected constant ratio 2.0 if forward models matched.')
print(f"  ls-scale CT->BL:  mean={df0.ls_scale_ct_to_bl.mean():.3f}  std={df0.ls_scale_ct_to_bl.std():.3f}  "
      f"min={df0.ls_scale_ct_to_bl.min():.3f}  max={df0.ls_scale_ct_to_bl.max():.3f}")
print(f"  PNG quantization RMSE vs EXR: mean={df0.png_vs_exr_rmse.mean():.5f} "
      f"(ideal 8-bit rounding floor ~= {1/(255*np.sqrt(12)):.5f})")
# Out:
#        ct_mean  bl_mean  mean_ratio_bl_ct  ls_scale_ct_to_bl  rmse_bl_vs_scaled_ct  corr_ct_bl  bl_px_over_1_pct  png_vs_exr_rmse
# light
# 0       0.1870   0.2342            1.2523             1.2332                0.0336      0.9732            0.0000           0.0000
# 1       0.2107   0.2522            1.1972             1.1714                0.0430      0.9682            0.0000           0.0000
# 2       0.0994   0.1111            1.1177             1.0328                0.0281      0.9315            0.0000           0.0000
# 3       0.1326   0.1841            1.3882             1.3618                0.0250      0.9783            0.0000           0.0000
# 4       0.1925   0.1936            1.0060             0.9764                0.0595      0.8922            0.0000           0.0000
# 5       0.0340   0.0717            2.1063             1.3939                0.0407      0.9092            0.0000           0.0000
# 6       0.1950   0.2219            1.1377             1.1397                0.0297      0.9730            0.0000           0.0000
# 7       0.0815   0.1242            1.5225             1.3069                0.0360      0.9609            0.0000           0.0000
# 8       0.0864   0.1209            1.4000             1.3042                0.0246      0.9750            0.0000           0.0000
# 9       0.1338   0.1422            1.0627             1.0089                0.0277      0.9666            0.0000           0.0000
# 10      0.0918   0.1532            1.6676             1.5627                0.0343      0.9486            0.0000           0.0000
# 11      0.2210   0.2651            1.1997             1.1684                0.0419      0.9748            0.0000           0.0000
# 12      0.1114   0.1151            1.0331             0.9779                0.0462      0.8113            0.0000           0.0000
# 13      0.0997   0.1098            1.1012             0.8448                0.0706      0.4084            0.0000           0.0000
# 14      0.1287   0.0742            0.5763             0.6196                0.0451      0.8209            0.0000           0.0000
# 15      0.1778   0.2134            1.2002             1.1631                0.0265      0.9804            0.0000           0.0000
#
# Summary: expected constant ratio 2.0 if forward models matched.
#   ls-scale CT->BL:  mean=1.142  std=0.231  min=0.620  max=1.563
#   PNG quantization RMSE vs EXR: mean=0.00000 (ideal 8-bit rounding floor ~= 0.00113)

# %%
# visual: CT render, Blender render (/2 for comparable brightness), abs difference
show_n = 4
fig, axes = plt.subplots(3, show_n, figsize=(3.0 * show_n, 9))
for c in range(show_n):
    ct, bl = np.asarray(ct_imgs[c]), bl_exr[c]
    axes[0, c].imshow(np.clip(ct, 0, 1));            axes[0, c].set_title(f'CT light_{c:03d}', fontsize=9)
    axes[1, c].imshow(np.clip(bl / ENV_STRENGTH, 0, 1)); axes[1, c].set_title(f'Blender env_{c} / 2', fontsize=9)
    d = np.abs(bl / ENV_STRENGTH - ct).mean(-1) * mask_np
    im = axes[2, c].imshow(d, cmap='inferno'); axes[2, c].set_title(f'|BL/2 - CT|  max={d.max():.3f}', fontsize=9)
    plt.colorbar(im, ax=axes[2, c], fraction=0.04)
for ax in axes.flat: ax.axis('off')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## E1 — Forward-model consistency with GT intrinsics + GT lighting
#
# No optimization anywhere here: we shade the **GT** albedo/roughness/metallic with the **known**
# lighting of light *i* and compare against the Blender EXR. Any residual is pure forward-model error —
# exactly the error floor the decomposition has to absorb by distorting intrinsics/lighting.
#
# Variants (all with GT intrinsics):
#
# | variant | lighting | shader | isolates |
# |---|---|---|---|
# | `sanity` | signed SH | `shade_ct_sh` vs **CT npy** | should be ≈ 0 (inverse crime check) |
# | `sh_x2` | signed SH × 2 | `shade_ct_sh` | the model actually used in decomposition |
# | `env_signed_x2` | signed SH env map × 2 | `shade_ct_env` | SH-filter vs explicit integration |
# | `env_rect_x2` | **rectified** SH env × 2 | `shade_ct_env` | + rectification (`max(·,0)`) |
# | `env_png_x2` | the actual 8-bit PNG × 2 (**exactly Blender's input**) | `shade_ct_env` | + quantization; remaining gap vs Blender ⇒ BSDF/geometry (H4/H5) |
#
# `ls_scale` = per-light least-squares scale model→Blender. If a *constant* scale fixed everything,
# the decomposition could absorb it in lighting ⇔ albedo scale; a *varying* scale / high scaled-RMSE cannot be absorbed.

# %%
def render_ct_sh_fwd(sh_np, light_scale=1.0, dtype=torch.float64, rough_override=None):
    t = T(dtype)
    sh_t = torch.from_numpy(np.asarray(sh_np)).to(DEVICE, dtype) * light_scale
    ro = t['ro'] if rough_override is None else torch.full_like(t['ro'], rough_override)
    with torch.no_grad():
        out = shade_ct_sh(t['V'], t['N'], t['ab'], sh_t,
                          metallic=t['me'], roughness=ro, lut=t['lut'])
    return scatter(out)

def render_ct_env_fwd(env_img, light_scale=1.0, dtype=torch.float64, rough_override=None):
    t = T(dtype)
    em = EnvMap(np.asarray(env_img, np.float32))
    pix  = torch.from_numpy(em._image_flat).to(DEVICE, dtype) * light_scale
    dirs = torch.from_numpy(em._dirs).to(DEVICE, dtype)
    dw   = torch.from_numpy(em._solid_angles).to(DEVICE, dtype)
    ro = t['ro'] if rough_override is None else torch.full_like(t['ro'], rough_override)
    with torch.no_grad():
        out = shade_ct_env(t['V'], t['N'], t['ab'], pix, dirs, dw,
                           metallic=t['me'], roughness=ro)
    return scatter(out)

def sh_env_signed_img(coeffs, resolution=64):
    '''SH -> equirect radiance WITHOUT the max(.,0) rectification of EnvMap.from_sh.'''
    H_, W_ = resolution // 2, resolution
    theta = np.pi * (np.arange(H_, dtype=np.float32) + 0.5) / H_
    phi   = 2 * np.pi * (np.arange(W_, dtype=np.float32) + 0.5) / W_ - np.pi
    st = np.sin(theta)[:, None]
    dirs = np.stack([st * np.cos(phi)[None, :],
                     np.broadcast_to(np.cos(theta)[:, None], (H_, W_)).copy(),
                     st * np.sin(phi)[None, :]], -1)
    return build_sh_basis(dirs) @ np.asarray(coeffs, np.float32)

recs, models_sh2, models_png = [], [], []
for i in range(N_CMP):
    tgt = bl_exr[i]
    signed = sh_env_signed_img(sh_gt[i])
    outs = {
        'sanity: sh vs CT npy': (render_ct_sh_fwd(sh_gt[i]), np.asarray(ct_imgs[i], np.float64)),
        'sh_x2 vs BL':          (render_ct_sh_fwd(sh_gt[i], ENV_STRENGTH), tgt),
        'env_signed_x2 vs BL':  (render_ct_env_fwd(signed, ENV_STRENGTH), tgt),
        'env_rect_x2 vs BL':    (render_ct_env_fwd(np.maximum(signed, 0.0), ENV_STRENGTH), tgt),
        'env_png_x2 vs BL':     (render_ct_env_fwd(env_png[i], ENV_STRENGTH), tgt),
    }
    models_sh2.append(outs['sh_x2 vs BL'][0])
    models_png.append(outs['env_png_x2 vs BL'][0])
    for name, (mdl, target) in outs.items():
        s, sr = opt_scale_rmse(mdl, target)
        recs.append(dict(variant=name, light=i, rmse=rmse(mdl, target),
                         ls_scale=float(s.mean()), rmse_after_scale=sr,
                         corr=pearson(mdl, target)))

df1 = pd.DataFrame(recs)
agg = df1.groupby('variant', sort=False).agg(
    rmse_mean=('rmse', 'mean'), rmse_max=('rmse', 'max'),
    scale_mean=('ls_scale', 'mean'), scale_std=('ls_scale', 'std'),
    rmse_scaled_mean=('rmse_after_scale', 'mean'), corr_mean=('corr', 'mean'))
print(agg.to_string())
print(f"\nreference points:  8-bit quantization floor ~{1/(255*np.sqrt(12)):.5f}   "
      f"| user's final recon RMSE on CT data ~0.0075, on Blender data ~0.02-0.04")
# Out:
#                       rmse_mean  rmse_max  scale_mean  scale_std  rmse_scaled_mean  corr_mean
# variant
# sanity: sh vs CT npy     0.0000    0.0000      1.0000     0.0000            0.0000     1.0000
# sh_x2 vs BL              0.1521    0.2330      0.5708     0.1153            0.0383     0.9045
# env_signed_x2 vs BL      0.1454    0.2144      0.5764     0.0932            0.0369     0.9350
# env_rect_x2 vs BL        0.1752    0.2284      0.5184     0.0781            0.0255     0.9651
# env_png_x2 vs BL         0.1734    0.2262      0.5214     0.0783            0.0255     0.9652
#
# reference points:  8-bit quantization floor ~0.00113   | user's final recon RMSE on CT data ~0.0075, on Blender data ~0.02-0.04

# %%
# per-light view of the same numbers (is the gap uniform across lights?)
piv = df1[df1.variant != 'sanity: sh vs CT npy'].pivot(index='light', columns='variant', values='rmse')
piv.plot(figsize=(10, 3.4), marker='o')
plt.ylabel('RMSE vs Blender EXR'); plt.title('E1: forward-model RMSE per light (GT intrinsics + GT lighting)')
plt.grid(alpha=0.3); plt.tight_layout(); plt.show()

pivs = df1[df1.variant != 'sanity: sh vs CT npy'].pivot(index='light', columns='variant', values='ls_scale')
pivs.plot(figsize=(10, 3.4), marker='o')
plt.axhline(1.0, color='k', lw=0.8)
plt.ylabel('LS scale model->Blender'); plt.title('E1: per-light least-squares scale (1.0 = energy match)')
plt.grid(alpha=0.3); plt.tight_layout(); plt.show()

# %%
# visual for one light: Blender vs the two extreme model variants + residuals
i = 0
fig, axes = plt.subplots(2, 3, figsize=(11, 7))
panels = [('Blender env_0 (EXR)', bl_exr[i]),
          ('ct_sh(sh x2), GT intrinsics', models_sh2[i]),
          ('ct_env(PNG x2), GT intrinsics', models_png[i])]
for c, (title, img) in enumerate(panels):
    axes[0, c].imshow(np.clip(img / ENV_STRENGTH, 0, 1)); axes[0, c].set_title(title, fontsize=9)
    if c == 0:
        axes[1, c].axis('off'); continue
    d = np.abs(img - bl_exr[i]).mean(-1) * mask_np
    im = axes[1, c].imshow(d, cmap='inferno', vmax=np.percentile(d, 99.5))
    axes[1, c].set_title(f'|model - BL|  rmse={rmse(img, bl_exr[i]):.4f}', fontsize=9)
    plt.colorbar(im, ax=axes[1, c], fraction=0.04)
for ax in axes.flat: ax.axis('off') if not ax.images else ax.set_xticks([]) or ax.set_yticks([])
plt.tight_layout(); plt.show()

# %% [markdown]
# ## E2 — Where does the residual live? (tests the low-roughness hypothesis)
#
# Per-pixel |model − Blender| averaged over the 16 lights, binned by **GT roughness**
# and split by metallic. If the user's low-roughness suspicion is right, the residual
# should blow up in the lowest-roughness bins — and we can check whether that residual is
# *numerical* (E3) or *structural* (rectified-lighting / BSDF mismatch).

# %%
res_sh  = np.stack([np.abs(masked(models_sh2[i]) - masked(bl_exr[i])).mean(-1) for i in range(N_CMP)]).mean(0)
res_png = np.stack([np.abs(masked(models_png[i]) - masked(bl_exr[i])).mean(-1) for i in range(N_CMP)]).mean(0)
tgt_mag = np.stack([masked(bl_exr[i]).mean(-1) for i in range(N_CMP)]).mean(0)
rr = masked(np.repeat(gt_rough, 3, axis=-1)).mean(-1)
mm = masked(np.repeat(gt_metal, 3, axis=-1)).mean(-1)

edges = np.unique(np.quantile(rr, np.linspace(0, 1, 13)))
bin_id = np.clip(np.digitize(rr, edges) - 1, 0, len(edges) - 2)
centers, abs_sh, abs_png, rel_sh, rel_png, counts = [], [], [], [], [], []
for b in range(len(edges) - 1):
    sel = bin_id == b
    if sel.sum() < 20: continue
    centers.append(rr[sel].mean()); counts.append(int(sel.sum()))
    abs_sh.append(res_sh[sel].mean());  abs_png.append(res_png[sel].mean())
    rel_sh.append(res_sh[sel].mean() / max(tgt_mag[sel].mean(), 1e-9))
    rel_png.append(res_png[sel].mean() / max(tgt_mag[sel].mean(), 1e-9))

fig, ax = plt.subplots(1, 2, figsize=(12, 3.8))
ax[0].plot(centers, abs_sh, 'o-', label='ct_sh(sh x2)')
ax[0].plot(centers, abs_png, 's-', label='ct_env(PNG x2)')
ax[0].set_xlabel('GT roughness (bin mean)'); ax[0].set_ylabel('mean |residual|')
ax[0].set_title('absolute residual vs roughness'); ax[0].legend(); ax[0].grid(alpha=0.3)
ax[1].plot(centers, rel_sh, 'o-', label='ct_sh(sh x2)')
ax[1].plot(centers, rel_png, 's-', label='ct_env(PNG x2)')
ax[1].set_xlabel('GT roughness (bin mean)'); ax[1].set_ylabel('|residual| / |target|')
ax[1].set_title('relative residual vs roughness'); ax[1].legend(); ax[1].grid(alpha=0.3)
plt.tight_layout(); plt.show()

print('metallic split (mean |residual|, ct_sh model):')
for name, sel in [('metallic > 0.5', mm > 0.5), ('dielectric <= 0.5', mm <= 0.5)]:
    print(f'  {name:18s} n={sel.sum():6d}  abs={res_sh[sel].mean():.4f}  '
          f'rel={res_sh[sel].mean()/max(tgt_mag[sel].mean(),1e-9):.3f}')

print('\nlow-roughness (r < 0.15) vs rest (ct_sh model):')
for name, sel in [('r < 0.15', rr < 0.15), ('r >= 0.15', rr >= 0.15)]:
    print(f'  {name:18s} n={sel.sum():6d}  abs={res_sh[sel].mean():.4f}  '
          f'rel={res_sh[sel].mean()/max(tgt_mag[sel].mean(),1e-9):.3f}')
# Out:
# metallic split (mean |residual|, ct_sh model):
#   metallic > 0.5     n=   878  abs=0.0639  rel=4.924
#   dielectric <= 0.5  n= 14498  abs=0.1201  rel=0.704
#
# low-roughness (r < 0.15) vs rest (ct_sh model):
#   r < 0.15           n=  6900  abs=0.0938  rel=0.704
#   r >= 0.15          n=  8476  abs=0.1357  rel=0.734

# %% [markdown]
# ## E3 — Numerical precision & quantization floors (tests H1/H2 directly)
#
# 1. Run the exact same forward pass in float32 and float64 (including a forced-roughness sweep
#    down to 0.0). If numerics were the problem, the f32/f64 difference would be comparable to the
#    observed residuals (~1e-2). If it is ~1e-6, H1 is refuted — float32 already suffices,
#    and float64 cannot be the missing ingredient.
# 2. Quantify what the 8-bit PNG dataset (`3dfront-dataset-env`, the plotted run) loses:
#    clipping >1 plus *truncating* (not rounding) quantization.

# %%
print('float32 vs float64 forward difference (GT intrinsics, light 0, lighting x2):')
print(f'{"roughness":>12s} {"ct_sh max|Δ|":>14s} {"ct_sh rmse":>12s} {"ct_env max|Δ|":>14s} {"ct_env rmse":>12s}')
for ro in [None, 0.0, 0.01, 0.05, 0.1, 0.3]:
    a64 = render_ct_sh_fwd(sh_gt[0], ENV_STRENGTH, torch.float64, ro)
    a32 = render_ct_sh_fwd(sh_gt[0], ENV_STRENGTH, torch.float32, ro)
    e64 = render_ct_env_fwd(env_png[0], ENV_STRENGTH, torch.float64, ro)
    e32 = render_ct_env_fwd(env_png[0], ENV_STRENGTH, torch.float32, ro)
    lab = 'GT map' if ro is None else f'{ro:.2f}'
    print(f'{lab:>12s} {np.abs(a64-a32).max():14.2e} {rmse(a64,a32):12.2e} '
          f'{np.abs(e64-e32).max():14.2e} {rmse(e64,e32):12.2e}')

print('\nquantization / clipping of the Blender image data:')
q_round = [rmse(np.round(np.clip(b,0,1)*255)/255, b) for b in bl_exr]
q_trunc = [rmse(np.floor(np.clip(b,0,1)*255)/255, b) for b in bl_exr]   # what save_png actually does
q_ds    = [rmse(bl_png[i], bl_exr[i]) for i in range(N_CMP)]
clip_frac = [float((masked(b) > 1.0).mean()) for b in bl_exr]
print(f'  ideal 8-bit rounding floor:        {1/(255*np.sqrt(12)):.5f}')
print(f'  round-quantized EXR vs EXR (mean): {np.mean(q_round):.5f}')
print(f'  trunc-quantized EXR vs EXR (mean): {np.mean(q_trunc):.5f}   <- save_png truncates')
print(f'  actual dataset PNG vs EXR (mean):  {np.mean(q_ds):.5f}')
print(f'  fraction of pixels clipped (>1):   {np.mean(clip_frac)*100:.3f}%')
print('\n  -> compare these floors against the E1 model-gap RMSE (~10-50x larger).')
# Out:
# float32 vs float64 forward difference (GT intrinsics, light 0, lighting x2):
#    roughness   ct_sh max|Δ|   ct_sh rmse  ct_env max|Δ|  ct_env rmse
#       GT map       2.31e-07     5.41e-08       7.25e-05     6.03e-07
#         0.00       2.18e-07     5.34e-08       3.10e-07     4.75e-08
#         0.01       2.28e-07     5.38e-08       1.11e-05     1.03e-07
#         0.05       2.21e-07     5.34e-08       7.01e-03     5.69e-05
#         0.10       2.31e-07     5.35e-08       8.26e-02     7.74e-04
#         0.30       2.26e-07     5.37e-08       1.56e-03     1.45e-05
#
# quantization / clipping of the Blender image data:
#   ideal 8-bit rounding floor:        0.00113
#   round-quantized EXR vs EXR (mean): 0.00000
#   trunc-quantized EXR vs EXR (mean): 0.00000   <- save_png truncates
#   actual dataset PNG vs EXR (mean):  0.00000
#   fraction of pixels clipped (>1):   0.000%
#
#   -> compare these floors against the E1 model-gap RMSE (~10-50x larger).

# %% [markdown]
# ## E4 — Best-achievable fit with a *free* SH light and **GT intrinsics**
#
# Now let the per-image SH lighting be optimized (as in decomposition) but keep albedo,
# roughness and metallic clamped to GT. This answers: *if the intrinsics were perfect,
# how well can the signed-order-2-SH lighting model explain each dataset?*
#
# - On **CT data** this must reach ≈ 0 (the data was generated by this very model).
# - On **Blender data** the remaining error is the irreducible model gap (H3+H4+H5 combined)
#   that the full decomposition instead absorbs by corrupting albedo/roughness/metallic.

# %%
def fit_sh_only(images, n_iter=100, label=''):
    cfg = {**DEFAULT_CFG, 'n_iter': n_iter, 'lbfgs_max_iter': 20, 'log_every': 25}
    print(f'--- SH-only fit: {label} ({len(images)} images) ---')
    albedo, sh_out, met, rou, shadings, history, elapsed = _optimize_ct_sh(
        images, normals_hw, frag_pos_hw, mask_hw, cam_pos,
        gt_metal, gt_rough, cfg,
        gt_albedo=gt_albedo, opt_params=frozenset({'sh'}),
    )
    per_img = [rmse(s, img) for s, img in zip(shadings, images)]
    print(f'  final loss={history[-1]:.3e}  recon RMSE mean={np.mean(per_img):.4f} '
          f' max={np.max(per_img):.4f}  ({elapsed:.0f}s)')
    return sh_out, shadings, per_img

sh_fit_ct, shad_ct, per_ct = fit_sh_only([np.asarray(im) for im in ct_imgs[:N_CMP]], label='CT data (control)')
sh_fit_bl, shad_bl, per_bl = fit_sh_only(bl_exr, label='Blender EXR data')
# Out:
# --- SH-only fit: CT data (control) (16 images) ---
#   [init]          loss=5.984e-01  data=5.984e-01  metallic=0.062  roughness=0.248
#   [   0]    1.3s  loss=2.064e-03  data=2.064e-03  metallic=0.062  roughness=0.248
#   [  25]   38.2s  loss=3.640e-04  data=3.640e-04  metallic=0.062  roughness=0.248
#   [  50]   40.9s  loss=3.640e-04  data=3.640e-04  metallic=0.062  roughness=0.248
#   [  75]   43.6s  loss=3.640e-04  data=3.640e-04  metallic=0.062  roughness=0.248
#   final loss=3.640e-04  recon RMSE mean=0.0122  max=0.0160  (46s)
# --- SH-only fit: Blender EXR data (16 images) ---
#   [init]          loss=4.836e-01  data=4.836e-01  metallic=0.062  roughness=0.248
#   [   0]    1.7s  loss=5.413e-03  data=5.413e-03  metallic=0.062  roughness=0.248
#   [  25]   30.7s  loss=4.581e-03  data=4.581e-03  metallic=0.062  roughness=0.248
#   [  50]   33.3s  loss=4.581e-03  data=4.581e-03  metallic=0.062  roughness=0.248
#   [  75]   35.9s  loss=4.581e-03  data=4.581e-03  metallic=0.062  roughness=0.248
#   final loss=4.581e-03  recon RMSE mean=0.0232  max=0.0305  (38s)

# %%
# How close is the fitted SH to the known GT SH (x2 for Blender)?
def sh_similarity(sh_fit, sh_ref_scaled):
    sims, scales = [], []
    for k in range(len(sh_ref_scaled)):
        a, b = sh_fit[k].ravel(), np.asarray(sh_ref_scaled[k], np.float32).ravel()
        scales.append(float((a @ b) / max(a @ a, 1e-12)))
        sims.append(float((a @ b) / (np.linalg.norm(a) * np.linalg.norm(b) + 1e-12)))
    return np.array(sims), np.array(scales)

sims_ct, sc_ct = sh_similarity(sh_fit_ct, [s for s in sh_gt[:N_CMP]])
sims_bl, sc_bl = sh_similarity(sh_fit_bl, [s * ENV_STRENGTH for s in sh_gt[:N_CMP]])
print(f'CT      : cosine(fit, GT SH)    mean={sims_ct.mean():.4f}  |  LS scale fit->GT mean={sc_ct.mean():.3f}')
print(f'Blender : cosine(fit, 2*GT SH)  mean={sims_bl.mean():.4f}  |  LS scale fit->GT mean={sc_bl.mean():.3f}')

plt.figure(figsize=(9, 3.2))
plt.plot(per_ct, 'o-', label=f'CT (mean {np.mean(per_ct):.4f})')
plt.plot(per_bl, 's-', label=f'Blender (mean {np.mean(per_bl):.4f})')
plt.xlabel('light index'); plt.ylabel('recon RMSE with GT intrinsics + fitted SH')
plt.title('E4: irreducible per-light model gap'); plt.legend(); plt.grid(alpha=0.3)
plt.tight_layout(); plt.show()

i = 0
fig, axes = plt.subplots(1, 3, figsize=(11, 3.6))
axes[0].imshow(np.clip(bl_exr[i] / ENV_STRENGTH, 0, 1)); axes[0].set_title('Blender env_0')
axes[1].imshow(np.clip(shad_bl[i] / ENV_STRENGTH, 0, 1)); axes[1].set_title('best SH fit (GT intrinsics)')
d = np.abs(shad_bl[i] - bl_exr[i]).mean(-1) * mask_np
im = axes[2].imshow(d, cmap='inferno'); axes[2].set_title(f'|fit - BL| rmse={per_bl[i]:.4f}')
plt.colorbar(im, ax=axes[2], fraction=0.04)
for ax in axes: ax.set_xticks([]); ax.set_yticks([])
plt.tight_layout(); plt.show()
# Out:
# CT      : cosine(fit, GT SH)    mean=0.8768  |  LS scale fit->GT mean=0.808
# Blender : cosine(fit, 2*GT SH)  mean=0.7415  |  LS scale fit->GT mean=1.685

# %% [markdown]
# ## E5 — Decomposition attribution (small runs, 16 images, user's config)
#
# Three decompositions with the *same* settings the user runs
# (sigmoid metallic/roughness, TV 1e-3, metallic-binarize 1e-3, init_roughness_zero, float64, L-BFGS):
#
# | run | data | lighting |
# |---|---|---|
# | **A control** | CT `.npy` | free |
# | **B full** | Blender EXR | free |
# | **C frozen light** | Blender EXR | **fixed to 2 × GT SH** (only intrinsics optimized) |
#
# If C recovers materials much better than B, the failure mode is lighting/albedo shell-game
# (the SH lights absorbing model mismatch and dragging albedo scale with them).
# If C is as bad as B, the residual is inherently forcing wrong materials.

# %%
USER_CFG = {**DEFAULT_CFG, 'n_iter': 200, 'lbfgs_max_iter': 20, 'log_every': 50,
            'lambda_tv': 1e-3, 'lambda_metallic_binarize': 1e-3,
            'tr_metallic': 'sigmoid', 'tr_roughness': 'sigmoid', 'tr_albedo': 'sigmoid',
            'init_roughness_zero': True}

def run_decomp(images, label, gt_sh=None, opt_params=None, n_iter=200):
    cfg = {**USER_CFG, 'n_iter': n_iter}
    print(f'=== E5 run: {label} ===')
    albedo, sh_out, met, rou, shadings, history, elapsed = _optimize_ct_sh(
        images, normals_hw, frag_pos_hw, mask_hw, cam_pos,
        gt_metal, gt_rough, cfg, gt_albedo=gt_albedo,
        gt_sh_coeffs=gt_sh, opt_params=opt_params)
    est = torch.from_numpy(albedo[mask_np]).double()
    gt  = torch.from_numpy(gt_albedo[mask_np]).double()
    armse, scale = _albedo_rmse(est, gt)
    summ = dict(label=label,
                albedo_rmse=float(armse), albedo_scale_mean=float(scale.mean()),
                metallic_rmse=float(np.sqrt(np.mean((met[mask_np] - gt_metal[mask_np])**2))),
                roughness_rmse=float(np.sqrt(np.mean((rou[mask_np] - gt_rough[mask_np])**2))),
                recon_rmse=float(np.mean([rmse(s, im) for s, im in zip(shadings, images)])),
                final_loss=float(history[-1]), elapsed_s=elapsed)
    print('   ', {k: (f'{v:.4f}' if isinstance(v, float) else v) for k, v in summ.items() if k != 'label'})
    return summ, dict(albedo=albedo, scale=scale.numpy(), met=met, rou=rou)

summs, maps = [], {}
s, m = run_decomp([np.asarray(im) for im in ct_imgs[:N_CMP]], 'A: CT data, free lighting (control)')
summs.append(s); maps['A'] = m
s, m = run_decomp(bl_exr, 'B: Blender EXR, free lighting')
summs.append(s); maps['B'] = m
s, m = run_decomp(bl_exr, 'C: Blender EXR, lighting frozen to 2xGT SH',
                  gt_sh=[np.asarray(sh * ENV_STRENGTH, np.float32) for sh in sh_gt[:N_CMP]],
                  opt_params=frozenset({'albedo', 'metallic', 'roughness'}))
summs.append(s); maps['C'] = m

df5 = pd.DataFrame(summs).set_index('label')
print('\n', df5.to_string())
# Out:
# === E5 run: A: CT data, free lighting (control) ===
#   [init]          loss=2.398e-01  data=2.395e-01  metallic=0.500  roughness=0.100
#   [   0]    1.1s  loss=5.565e-03  data=5.301e-03  metallic=0.499  roughness=0.100
#   [  50]   92.2s  loss=5.744e-04  data=3.835e-04  metallic=0.206  roughness=0.106
#   [ 100]  188.2s  loss=2.209e-04  data=1.400e-04  metallic=0.083  roughness=0.119
#   [ 150]  283.8s  loss=1.524e-04  data=8.549e-05  metallic=0.069  roughness=0.130
#     {'albedo_rmse': '0.0683', 'albedo_scale_mean': '1.6858', 'metallic_rmse': '0.0851', 'roughness_rmse': '0.2381', 'recon_rmse': '0.0114', 'final_loss': '0.0002', 'elapsed_s': '379.6027'}
# === E5 run: B: Blender EXR, free lighting ===
#   [init]          loss=3.086e-01  data=3.083e-01  metallic=0.500  roughness=0.100
#   [   0]    1.0s  loss=7.456e-03  data=7.188e-03  metallic=0.499  roughness=0.100
#   [  50]   94.4s  loss=1.126e-03  data=8.804e-04  metallic=0.300  roughness=0.102
#   [ 100]  190.0s  loss=9.062e-04  data=7.647e-04  metallic=0.138  roughness=0.106
#   [ 150]  285.7s  loss=8.537e-04  data=7.416e-04  metallic=0.104  roughness=0.108
#     {'albedo_rmse': '0.2192', 'albedo_scale_mean': '1.4190', 'metallic_rmse': '0.2425', 'roughness_rmse': '0.2723', 'recon_rmse': '0.0183', 'final_loss': '0.0009', 'elapsed_s': '380.4552'}
# === E5 run: C: Blender EXR, lighting frozen to 2xGT SH ===
#   [init]          loss=2.349e-01  data=2.346e-01  metallic=0.500  roughness=0.100
#   [   0]    0.8s  loss=2.859e-02  data=2.844e-02  metallic=0.119  roughness=0.255
#   [  50]   16.4s  loss=1.854e-02  data=1.845e-02  metallic=0.108  roughness=0.970
#   [ 100]   17.8s  loss=1.854e-02  data=1.845e-02  metallic=0.108  roughness=0.970
#   [ 150]   19.2s  loss=1.854e-02  data=1.845e-02  metallic=0.108  roughness=0.970
#     {'albedo_rmse': '0.1025', 'albedo_scale_mean': '1.7652', 'metallic_rmse': '0.2200', 'roughness_rmse': '0.7656', 'recon_rmse': '0.0361', 'final_loss': '0.0185', 'elapsed_s': '20.5400'}
#
#                                              albedo_rmse  albedo_scale_mean  metallic_rmse  roughness_rmse  recon_rmse  final_loss  elapsed_s
# label
# A: CT data, free lighting (control)              0.0683             1.6858         0.0851          0.2381      0.0114      0.0002   379.6027
# B: Blender EXR, free lighting                    0.2192             1.4190         0.2425          0.2723      0.0183      0.0009   380.4552
# C: Blender EXR, lighting frozen to 2xGT SH       0.1025             1.7652         0.2200          0.7656      0.0361      0.0185    20.5400

# %%
# estimated maps side by side
fig, axes = plt.subplots(4, 4, figsize=(13, 13))
col_titles = ['GT'] + [f'run {k}' for k in ['A', 'B', 'C']]
row_data = [
    ('albedo (scaled to GT)', gt_albedo,
     [np.clip(maps[k]['albedo'] * maps[k]['scale'][None, None, :], 0, 1) * mask_np[:, :, None] for k in 'ABC']),
    ('albedo (raw estimate)', gt_albedo,
     [np.clip(maps[k]['albedo'], 0, 1) * mask_np[:, :, None] for k in 'ABC']),
    ('roughness', gt_rough.squeeze(-1),
     [maps[k]['rou'].squeeze(-1) * mask_np for k in 'ABC']),
    ('metallic', gt_metal.squeeze(-1),
     [maps[k]['met'].squeeze(-1) * mask_np for k in 'ABC']),
]
for r, (name, gt_img, ests) in enumerate(row_data):
    for c, img in enumerate([gt_img] + ests):
        kw = dict(cmap='gray', vmin=0, vmax=1) if img.ndim == 2 else {}
        axes[r, c].imshow(img, **kw)
        axes[r, c].set_title(f'{col_titles[c]} — {name}', fontsize=8)
        axes[r, c].axis('off')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## E6 — Root-cause hunt: where does the missing energy go?
#
# E1 left a puzzle: even with **GT intrinsics and Blender's exact env input**, the model is
# ~1.9× brighter than the Blender render, with a per-light scale (0.31–0.64) that is
# **spatially almost flat**. E2/E3 ruled out numerics and quantization. This section documents
# the controlled render experiments (scripts: `test_sphere_roomlike.py`, `front3d_env_probe.py`
# in the BlenderProc example folder; outputs in `results/mis_bounce_test/`) that isolated the cause.
#
# Steps (each render uses the same env-world node graph as `render_front3d_multipass.py`,
# `sh_env_map_000.png`, strength 2.0, Cycles `max_bounces=0` unless noted):
#
# 1. **Background sanity (sphere render, background pixels):** background = `env × 2.0` exactly
#    (LS scale 1.02, corr 0.99) ⇒ strength applied, no output/exposure scaling, orientation correct.
# 2. **White-diffuse sphere, open scene:** Blender = analytic Lambert prediction to 0.3 %
#    (ratio 1.000) ⇒ Blender's *direct env transport is exact in an open scene*, CT model exact too.
# 3. **Room probe (real 3D-FRONT view, `material_override` = white diffuse):**
#    ratio **0.59, flat** (p10 0.56 / p90 0.62). With shadows ON: 0.07 ⇒ `visible_shadow=False`
#    works, room is nearly closed. Materials are *eliminated* as the cause.
# 4. **Minimal repro:** the same white sphere inside a shadow-culled 20 m box → ratio **0.562 flat**
#    — the room deficit reproduced with two objects.
# 5. **Bisection:** box hidden from camera → no change; box moved aside → 1.0;
#    light tree off → no change; `transparent_max_bounces=1024` → no change;
#    manual world importance map → no change; box rotated 45° → bit-identical;
#    θ-band env maps → equator bands deliver **0.49**, polar bands **0.91**;
#    constant white env → **0.178**.
# 6. **Fix test:** disable **all** secondary-ray visibility on the box
#    (`visible_diffuse/glossy/transmission/volume_scatter/shadow = False`) → ratio **1.000** exact.
#
# ### Mechanism
#
# Cycles splits background lighting between **light sampling (NEE)** and **BSDF sampling** via MIS.
# The BSDF-sampled share is only collected when a BSDF-sampled continuation ray *escapes the scene
# and hits the background*. With `max_bounces = 0` **indoors**, every BSDF-sampled ray hits
# surrounding geometry — which is still visible to diffuse/glossy rays even though
# `visible_shadow=False` was set — and the path dies there. Only the NEE part (MIS weight < 1)
# survives ⇒ a per-light, direction-dependent energy loss:
#
# - lost fraction = the BSDF-side MIS weight, largest where the equirect light-sampling pdf is
#   low relative to the cosine lobe (equator bands 0.49 vs poles 0.91, constant env 0.18);
# - in an open scene the BSDF ray reaches the background and the two halves sum exactly to 1.000;
# - the effective lighting indoors is **not a scaled version of the env map** — it is warped in a
#   direction-dependent way that no SH lighting estimate can reproduce together with the true
#   intrinsics. This is the root cause of the poor Blender-data decompositions.

# %%
import os
import sys, json
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
# Repo root, found by walking up from the CWD. Notebooks live in notebooks/, but the
# code and the relative data paths below are relative to the repo root, so chdir there.
REPO = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "idr").is_dir())
os.chdir(REPO)
if str(REPO) not in sys.path:
    sys.path.insert(0, str(REPO))
from idr.data.scene_io import load_exr
from idr.render import EnvMap

MBT = Path('results/mis_bounce_test')

# analytic sphere-test geometry (512x512, Blender default 50mm/36mm lens, cam at (0,0,-3) in cam space)
Hs = Ws = 512; tx = 18/50
ys = np.linspace(1, -1, Hs, dtype=np.float32); xs = np.linspace(-1, 1, Ws, dtype=np.float32)
xg, yg = np.meshgrid(xs, ys)
d = np.stack([xg*tx, yg*tx, -np.ones_like(xg)], -1); d /= np.linalg.norm(d, axis=-1, keepdims=True)
sil = np.sqrt(1 - d[..., 2]**2)
FG = sil < 0.90/3                      # strictly-interior sphere pixels
C = np.array([0, 0, -3], np.float32)
b = d @ C; t = b - np.sqrt(np.maximum(b**2 - (C@C - 1), 0))
P = t[..., None]*d; NS = P - C; NS /= np.linalg.norm(NS, axis=-1, keepdims=True)

def lambert_pred(env_png_path, normals, strength=2.0):
    png = np.array(Image.open(env_png_path), np.float32)[:, :, :3] / 255
    em = EnvMap(png)
    return (np.maximum(normals @ em._dirs.T, 0) * em._solid_angles) @ em._image_flat * strength / np.pi

ENV0 = 'results/ref_lighting/dclift/sh_env_map_000.png'
pred_sphere = lambert_pred(ENV0, NS[FG])

sphere_runs = [
    ('sphere_white_b0',          'open scene (control)'),
    ('sphere_white_box_b0',      '+ shadow-culled 20m box'),
    ('sphere_white_box_hidecam', 'box also camera-hidden'),
    ('sphere_white_box_rot45',   'box rotated 45°'),
    ('sphere_white_box_manual',  'manual world importance map'),
    ('sphere_white_box_offset',  'box moved aside (not enclosing)'),
    ('sphere_white_plane1',      '1 culled plane crossing rays'),
    ('sphere_white_plane2',      '2 culled planes'),
    ('sphere_white_box_hidesec', 'box: ALL secondary visibility off (FIX)'),
]
rows = []
for tag, desc in sphere_runs:
    obs = load_exr(str(MBT / tag / 'rendering.exr'))[FG]
    rat = obs.mean(-1) / np.maximum(pred_sphere.mean(-1), 1e-6)
    rows.append(dict(variant=desc, ratio_median=np.median(rat),
                     p10=np.percentile(rat, 10), p90=np.percentile(rat, 90)))
# constant-white env inside the box
pred_c = lambert_pred(str(MBT / 'const_white_env.png'), NS[FG])
obs = load_exr(str(MBT / 'sphere_white_box_constenv' / 'rendering.exr'))[FG]
rat = obs.mean(-1) / np.maximum(pred_c.mean(-1), 1e-6)
rows.append(dict(variant='box + CONSTANT white env', ratio_median=np.median(rat),
                 p10=np.percentile(rat, 10), p90=np.percentile(rat, 90)))
df6 = pd.DataFrame(rows).set_index('variant')
print('White-diffuse sphere, env x2, max_bounces=0 — Blender / analytic-Lambert ratio:')
print(df6.round(3).to_string())
# Out:
# White-diffuse sphere, env x2, max_bounces=0 — Blender / analytic-Lambert ratio:
#                                          ratio_median    p10    p90
# variant
# open scene (control)                           1.0000 0.9970 1.0040
# + shadow-culled 20m box                        0.5620 0.5420 0.5870
# box also camera-hidden                         0.5620 0.5420 0.5870
# box rotated 45°                                0.5620 0.5420 0.5870
# manual world importance map                    0.5620 0.5420 0.5870
# box moved aside (not enclosing)                0.9890 0.9620 1.0020
# 1 culled plane crossing rays                   1.0000 0.9970 1.0030
# 2 culled planes                                1.0000 0.9970 1.0030
# box: ALL secondary visibility off (FIX)        1.0000 0.9970 1.0040
# box + CONSTANT white env                       0.1780 0.1760 0.1780

# %%
# directional transfer profile inside the box: theta-band env maps
centers, meds, p10s, p90s = [], [], [], []
for bi in range(4):
    pred = lambert_pred(str(MBT / f'band_theta{bi}.png'), NS[FG])
    obs = load_exr(str(MBT / f'sphere_white_box_band{bi}' / 'rendering.exr'))[FG]
    sel = pred.mean(-1) > 0.02
    rat = obs[sel].mean(-1) / pred[sel].mean(-1)
    centers.append(bi*45 + 22.5)
    meds.append(np.median(rat)); p10s.append(np.percentile(rat, 10)); p90s.append(np.percentile(rat, 90))
plt.figure(figsize=(7, 3.2))
plt.errorbar(centers, meds,
             yerr=[np.array(meds)-np.array(p10s), np.array(p90s)-np.array(meds)],
             fmt='o-', capsize=4)
plt.axhline(1.0, color='k', lw=0.8)
plt.xlabel('env-map polar angle θ of the light band (deg, camera space)')
plt.ylabel('delivered / expected')
plt.title('E6: direction-dependent env-light loss inside shadow-culled enclosure (bounces=0)')
plt.grid(alpha=0.3); plt.ylim(0, 1.1); plt.tight_layout(); plt.show()
print('equator bands lose ~2x more than polar bands -> the effective lighting is a *warped*, '
      'not scaled, version of the env map.')
# Out:
# equator bands lose ~2x more than polar bands -> the effective lighting is a *warped*, not scaled, version of the env map.

# %%
# room probe: real 3D-FRONT view, material_override = white diffuse
# (uses the dataset copy of the GT normals; geometry is deterministic, so they remain valid)
n8 = np.array(Image.open('results/3dfront-dataset-sh/normals.png'), np.float32)
rm_mask = n8.sum(-1) > 0
nr = n8/255*2 - 1; nr /= np.maximum(np.linalg.norm(nr, axis=-1, keepdims=True), 1e-6)
pred_room = lambert_pred(ENV0, nr[rm_mask])
print('Room probe (white-diffuse override, env_000 x2, bounces=0):')
for tag, desc in [('probe_white_noshadow',             'shadows disabled (dataset setting)'),
                  ('probe_white_shadow',               'shadows enabled (occlusion check)'),
                  ('probe_white_noshadow_nolighttree', 'light tree disabled'),
                  ('probe_white_noshadow_tb1024',      'transparent_max_bounces=1024')]:
    obs = load_exr(str(MBT / 'room_probe' / f'{tag}.exr'))[rm_mask]
    rat = obs.mean(-1) / np.maximum(pred_room.mean(-1), 1e-6)
    print(f'  {desc:38s} ratio median={np.median(rat):.3f}  p10={np.percentile(rat,10):.3f}  '
          f'p90={np.percentile(rat,90):.3f}')
# Out:
# Room probe (white-diffuse override, env_000 x2, bounces=0):
#   shadows disabled (dataset setting)     ratio median=0.590  p10=0.560  p90=0.621
#   shadows enabled (occlusion check)      ratio median=0.072  p10=0.021  p90=0.122
#   light tree disabled                    ratio median=0.590  p10=0.560  p90=0.621
#   transparent_max_bounces=1024           ratio median=0.590  p10=0.560  p90=0.621

# %% [markdown]
# ### The fix (verified: restores exact agreement)
#
# In `render_front3d_multipass.py`, `_set_mesh_shadow_visibility(False)` must disable **all
# secondary-ray visibility** during env renders, not only `visible_shadow` — then every
# BSDF-sampled ray escapes to the background and the direct env lighting is exact even at
# `max_bounces = 0`:
#
# ```python
# def _set_mesh_secondary_visibility(enabled: bool) -> None:
#     for obj in bpy.data.objects:
#         if obj.type != 'MESH':
#             continue
#         obj.visible_shadow        = enabled
#         obj.visible_diffuse       = enabled   # <- these three are the missing piece
#         obj.visible_glossy        = enabled
#         obj.visible_transmission  = enabled
#         obj.visible_volume_scatter = enabled
# ```
#
# Side effect (desirable here): glossy surfaces then reflect the env map instead of other room
# geometry — exactly what the CT forward model (no interreflections, no visibility) assumes.
#
# **The env dataset has been re-rendered with this fix (2026-07-03, old data preserved in output/backup 260703) — see E7 below for validation.**
# While re-rendering, also fix the second data bug found in E3: `bproc.renderer.render()`
# returns the 8-bit PNG it writes by default, so the current "EXR" files are uint8-quantized
# (and clipped at 1.0). Call `bproc.renderer.set_output_format(file_format="OPEN_EXR")`
# (or route the beauty pass through a float compositor output) so `env_i.exr` is true float HDR.

# %% [markdown]
# ## E7 — Validation on the re-rendered dataset (fixes applied)
#
# Both fixes were applied to `render_front3d_multipass.py` and the env condition of scene
# `00004f89` / view 1 was re-rendered (2026-07-03, same camera pose and the same 128 env maps,
# replayed from `accepted_setup.json`; the old dataset lives in `E:\3D-Front\output\backup 260703\`,
# the fixed one in `E:\3D-Front\output\`):
#
# 1. `_set_mesh_shadow_visibility` now disables **all** secondary-ray visibility
#    (diffuse/glossy/transmission/volume-scatter/shadow) during env renders — restores the
#    BSDF-sampled MIS share of the env light that was being lost (E6).
# 2. `bproc.renderer.set_output_format(file_format="OPEN_EXR", color_depth=32)` — beauty
#    renders now come back as float, so `env_i.exr` is true HDR (the `arr.max()>1.5` uint8
#    heuristics in the save helpers were replaced with dtype checks, since genuine HDR values
#    can exceed 1.5).
#
# Note: material randomization is not seeded by the replay, so the *materials* (cc floor etc.)
# differ from the old run — the GT maps were re-captured in the same run, so the data is
# self-consistent, but old-vs-new comparisons are per-pipeline, not per-pixel.

# %%
import os
import sys, json
from pathlib import Path
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
# Repo root, found by walking up from the CWD. Notebooks live in notebooks/, but the
# code and the relative data paths below are relative to the repo root, so chdir there.
REPO = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "idr").is_dir())
os.chdir(REPO)
if str(REPO) not in sys.path:
    sys.path.insert(0, str(REPO))
from idr.data.geometry import make_proxy_geometry
from idr.data.scene_io import load_exr
from idr.config import DEFAULT_CFG
from idr.optim.models.ct_sh import _optimize_ct_sh
from idr.eval.metrics import _albedo_rmse
from idr.render import EnvMap, shade_ct_env, shade_ct_sh
from idr.render.brdf import _get_ggx_sh_lut

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
NEW = Path(r'E:\3D-Front\output\00004f89-9aa5-43c2-ae3c-129586be8aaa\1')
OLD = Path(r'E:\3D-Front\output\backup 260703\00004f89-9aa5-43c2-ae3c-129586be8aaa\1')
REF_SH = Path('results/ref_lighting/dclift')
ENV_STRENGTH = 2.0
N_CHK = 16

# ---- new GT maps (materials were re-randomized, so re-load everything) -------
def load_gt(folder):
    norm_raw = np.array(Image.open(folder / 'normals.png'), np.float32)
    mask = norm_raw.sum(-1) > 0
    normals = norm_raw / 255 * 2 - 1
    normals /= np.maximum(np.linalg.norm(normals, axis=-1, keepdims=True), 1e-6)
    albedo = np.array(Image.open(folder / 'albedo.png'), np.float32)[:, :, :3] / 255
    rough = (np.array(Image.open(folder / 'roughness.png'), np.float32) / 65535.0)[:, :, None]
    metal = (np.array(Image.open(folder / 'metallic.png'), np.float32) / 65535.0)[:, :, None]
    return dict(normals=normals, mask=mask, albedo=albedo, rough=rough, metal=metal)

gt = load_gt(NEW)
H, W = gt['mask'].shape
mask_flat = gt['mask'].reshape(-1)
print(f'new GT: roughness mean={gt["rough"][gt["mask"]].mean():.3f}  '
      f'metallic mean={gt["metal"][gt["mask"]].mean():.3f}  (old run was 0.248 / 0.062)')

# proxy geometry (float64), same convention as the decompositions
n_hw, f_hw, m_hw, cam = make_proxy_geometry(gt['normals'], gt['mask'], device=DEVICE,
                                            dtype=torch.float64)
fm = m_hw.reshape(-1)
N_m = n_hw.reshape(-1, 3)[fm]
V_m = torch.nn.functional.normalize(cam.unsqueeze(0) - f_hw.reshape(-1, 3)[fm], dim=-1)
def fl(a):
    t = torch.from_numpy(np.ascontiguousarray(a, np.float64)).to(DEVICE)
    return t.reshape(-1, t.shape[-1])[fm]
A_m, R_m, M_m = fl(gt['albedo']), fl(gt['rough']), fl(gt['metal'])
LUT = _get_ggx_sh_lut(DEVICE).to(torch.float64)

def masked(img): return np.asarray(img, np.float64).reshape(-1, 3)[mask_flat]
def scatter(t):
    out = np.zeros((H * W, 3)); out[mask_flat] = t.detach().cpu().numpy()
    return out.reshape(H, W, 3)
def rmse(a, b): return float(np.sqrt(np.mean((masked(a) - masked(b))**2)))
def opt_scale_rmse(mod, tgt):
    m, t = masked(mod), masked(tgt)
    s = (t * m).sum(0) / np.maximum((m * m).sum(0), 1e-12)
    return s, float(np.sqrt(np.mean((m * s - t)**2)))
def pearson(a, b): return float(np.corrcoef(masked(a).ravel(), masked(b).ravel())[0, 1])

def fwd_env(env_img, scale):
    em = EnvMap(np.asarray(env_img, np.float32))
    pix = torch.from_numpy(em._image_flat).to(DEVICE, torch.float64) * scale
    dirs = torch.from_numpy(em._dirs).to(DEVICE, torch.float64)
    dw = torch.from_numpy(em._solid_angles).to(DEVICE, torch.float64)
    with torch.no_grad():
        return scatter(shade_ct_env(V_m, N_m, A_m, pix, dirs, dw, metallic=M_m, roughness=R_m))
def fwd_sh(sh, scale):
    sh_t = torch.from_numpy(np.asarray(sh)).to(DEVICE, torch.float64) * scale
    with torch.no_grad():
        return scatter(shade_ct_sh(V_m, N_m, A_m, sh_t, metallic=M_m, roughness=R_m, lut=LUT))

# ---- is the new EXR real float HDR? ------------------------------------------
bl_new = [load_exr(NEW / f'env_{i}.exr').astype(np.float64) for i in range(N_CHK)]
q = max(float(np.abs(b * 255 - np.round(b * 255)).max()) for b in bl_new)
over1 = np.mean([float((masked(b) > 1.0).mean()) for b in bl_new])
print(f'uint8-grid deviation of new EXRs: {q:.3f} (old data: 0.000 -> was uint8; now real float)')
print(f'fraction of masked pixels > 1.0: {over1*100:.3f}% (old data: exactly 0 -> was clipped)')
# Out:
# new GT: roughness mean=0.215  metallic mean=0.009  (old run was 0.248 / 0.062)
# uint8-grid deviation of new EXRs: 0.500 (old data: 0.000 -> was uint8; now real float)
# fraction of masked pixels > 1.0: 0.046% (old data: exactly 0 -> was clipped)

# %%
# ---- forward-model consistency on the FIXED data (E1 repeated) ----------------
env_png = [np.array(Image.open(REF_SH / f'sh_env_map_{i:03d}.png'), np.float64)[:, :, :3] / 255
           for i in range(N_CHK)]
sh_gt = [np.load(REF_SH / f'sh_{i:03d}.npy').astype(np.float64) for i in range(N_CHK)]

recs = []
models_png_new = []
for i in range(N_CHK):
    tgt = bl_new[i]
    for name, mod in [('env_png_x2 vs BL(fixed)', fwd_env(env_png[i], ENV_STRENGTH)),
                      ('sh_x2 vs BL(fixed)',      fwd_sh(sh_gt[i], ENV_STRENGTH))]:
        if name.startswith('env_png'):
            models_png_new.append(mod)
        s, sr = opt_scale_rmse(mod, tgt)
        recs.append(dict(variant=name, light=i, rmse=rmse(mod, tgt), ls_scale=float(s.mean()),
                         rmse_after_scale=sr, corr=pearson(mod, tgt)))
df7 = pd.DataFrame(recs)
agg7 = df7.groupby('variant', sort=False).agg(
    rmse_mean=('rmse', 'mean'), scale_mean=('ls_scale', 'mean'), scale_std=('ls_scale', 'std'),
    rmse_scaled_mean=('rmse_after_scale', 'mean'), corr_mean=('corr', 'mean'))
print('GT intrinsics + GT lighting vs the FIXED Blender renders:')
print(agg7.round(4).to_string())
print('\nfor comparison, E1 on the OLD renders: env_png_x2 scale 0.52 / rmse 0.173 / '
      'rmse_scaled 0.026 | sh_x2 scale 0.57 / rmse 0.152 / rmse_scaled 0.038')

# residual on metallic vs dielectric pixels
res = np.stack([np.abs(masked(models_png_new[i]) - masked(bl_new[i])).mean(-1)
                for i in range(N_CHK)]).mean(0)
tgt_mag = np.stack([masked(bl_new[i]).mean(-1) for i in range(N_CHK)]).mean(0)
mm = masked(np.repeat(gt['metal'], 3, axis=-1)).mean(-1)
for name, sel in [('metallic > 0.5', mm > 0.5), ('dielectric <= 0.5', mm <= 0.5)]:
    if sel.sum() == 0:
        print(f'  {name}: no pixels'); continue
    print(f'  {name:18s} n={sel.sum():6d}  |residual|={res[sel].mean():.4f}  '
          f'relative={res[sel].mean()/max(tgt_mag[sel].mean(),1e-9):.3f}   '
          f'(old: 4.92 metallic / 0.70 dielectric)')
# Out:
# GT intrinsics + GT lighting vs the FIXED Blender renders:
#                          rmse_mean  scale_mean  scale_std  rmse_scaled_mean  corr_mean
# variant
# env_png_x2 vs BL(fixed)     0.0495      1.0005     0.0273            0.0486     0.9611
# sh_x2 vs BL(fixed)          0.0652      1.1005     0.0819            0.0568     0.9509
#
# for comparison, E1 on the OLD renders: env_png_x2 scale 0.52 / rmse 0.173 / rmse_scaled 0.026 | sh_x2 scale 0.57 / rmse 0.152 / rmse_scaled 0.038
#   metallic > 0.5: no pixels
#   dielectric <= 0.5  n= 15376  |residual|=0.0242  relative=0.087   (old: 4.92 metallic / 0.70 dielectric)

# %%
# ---- visual check: old render, new render, model, ratio map -------------------
i = 0
mod = models_png_new[i]
old_img = load_exr(OLD / f'env_{i}.exr').astype(np.float64)
fig, ax = plt.subplots(1, 4, figsize=(16, 4))
ax[0].imshow(np.clip(old_img / ENV_STRENGTH, 0, 1)); ax[0].set_title('OLD env_0 (buggy)')
ax[1].imshow(np.clip(bl_new[i] / ENV_STRENGTH, 0, 1)); ax[1].set_title('NEW env_0 (fixed)')
ax[2].imshow(np.clip(mod / ENV_STRENGTH, 0, 1)); ax[2].set_title('CT-env model (GT, PNGx2)')
r = np.where(mod.mean(-1) > 0.02, bl_new[i].mean(-1) / np.maximum(mod.mean(-1), 1e-6), np.nan)
im = ax[3].imshow(r, cmap='RdBu_r', vmin=0, vmax=2)
ax[3].set_title(f'ratio NEW/model  med={np.nanmedian(r):.2f}  (old was ~0.6)')
plt.colorbar(im, ax=ax[3], fraction=0.04)
for a in ax: a.axis('off')
plt.tight_layout(); plt.show()

# %%
# ---- decomposition on the fixed data (same config as E5 run B) -----------------
USER_CFG = {**DEFAULT_CFG, 'n_iter': 200, 'lbfgs_max_iter': 20, 'log_every': 50,
            'lambda_tv': 1e-3, 'lambda_metallic_binarize': 1e-3,
            'tr_metallic': 'sigmoid', 'tr_roughness': 'sigmoid', 'tr_albedo': 'sigmoid',
            'init_roughness_zero': True}
albedo, sh_out, met, rou, shadings, history, elapsed = _optimize_ct_sh(
    bl_new, n_hw, f_hw, m_hw, cam,
    gt['metal'], gt['rough'], USER_CFG, gt_albedo=gt['albedo'])
est = torch.from_numpy(albedo[gt['mask']]).double()
gtt = torch.from_numpy(gt['albedo'][gt['mask']]).double()
armse, scale = _albedo_rmse(est, gtt)
summary = dict(
    albedo_rmse=float(armse), albedo_scale_mean=float(scale.mean()),
    metallic_rmse=float(np.sqrt(np.mean((met[gt['mask']] - gt['metal'][gt['mask']])**2))),
    roughness_rmse=float(np.sqrt(np.mean((rou[gt['mask']] - gt['rough'][gt['mask']])**2))),
    recon_rmse=float(np.mean([rmse(s, im_) for s, im_ in zip(shadings, bl_new)])),
    final_loss=float(history[-1]))
print('\ndecomposition on FIXED Blender data (16 imgs, 200 iters, user config):')
print({k: round(v, 4) for k, v in summary.items()})
print('\nE5 reference (same config): '
      'A CT control: albedo_rmse 0.059, scale 1.51, metallic 0.22, roughness 0.23, recon 0.011 | '
      'B OLD Blender: albedo_rmse 0.277, scale 0.48, metallic 0.27, roughness 0.27, recon 0.020')
# Out:
#   [init]          loss=8.453e-01  data=8.450e-01  metallic=0.500  roughness=0.100
#   [   0]    0.9s  loss=2.534e-02  data=2.506e-02  metallic=0.499  roughness=0.100
#   [  50]   91.8s  loss=4.635e-03  data=4.343e-03  metallic=0.278  roughness=0.115
#   [ 100]  190.5s  loss=3.911e-03  data=3.642e-03  metallic=0.194  roughness=0.145
#   [ 150]  288.2s  loss=3.532e-03  data=3.275e-03  metallic=0.157  roughness=0.179
# decomposition on FIXED Blender data (16 imgs, 200 iters, user config):
# {'albedo_rmse': 0.1858, 'albedo_scale_mean': 1.493, 'metallic_rmse': 0.2295, 'roughness_rmse': 0.297, 'recon_rmse': 0.0397, 'final_loss': 0.0035}
#
# E5 reference (same config): A CT control: albedo_rmse 0.059, scale 1.51, metallic 0.22, roughness 0.23, recon 0.011 | B OLD Blender: albedo_rmse 0.277, scale 0.48, metallic 0.27, roughness 0.27, recon 0.020

# %%
# ---- estimated maps on the fixed data ------------------------------------------
fig, axes = plt.subplots(2, 4, figsize=(14, 7))
panels = [
    ('GT albedo', gt['albedo']), ('est albedo (scaled)',
        np.clip(albedo * scale.numpy()[None, None, :], 0, 1) * gt['mask'][:, :, None]),
    ('GT roughness', gt['rough'].squeeze(-1)), ('est roughness', rou.squeeze(-1) * gt['mask']),
    ('GT metallic', gt['metal'].squeeze(-1)), ('est metallic', met.squeeze(-1) * gt['mask']),
    ('observed env_0 (fixed)', np.clip(bl_new[0] / ENV_STRENGTH, 0, 1)),
    ('reconstruction env_0', np.clip(shadings[0] / ENV_STRENGTH, 0, 1)),
]
for axi, (title, img) in zip(axes.flat, panels):
    kw = dict(cmap='gray', vmin=0, vmax=1) if img.ndim == 2 else {}
    axi.imshow(img, **kw); axi.set_title(title, fontsize=9); axi.axis('off')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Conclusions
#
# **The user hypothesis (H1, float64/EXR-resistant numerical issues at low roughness) is refuted;
# the actual cause is a light-transport bug in how the BlenderProc env dataset was rendered (H4-adjacent),
# plus a secondary data-quantization bug.**
#
# | # | Finding | Evidence |
# |---|---|---|
# | 1 | **Root cause:** with `max_bounces=0`, indoor env renders lose the BSDF-sampled MIS share of the env light, because surrounding geometry is still diffuse/glossy-visible (only `visible_shadow` was disabled). Loss is ~40 % on average, per-light (0.31–0.64) and direction-dependent (equator 0.49 vs poles 0.91) — the effective lighting is a *warped* env no SH estimate can match together with the true intrinsics. | E1 (flat per-light scale ~0.52–0.58), E6 minimal repro + fix (0.562 → 1.000) |
# | 2 | **Fix:** disable all secondary-ray visibility on meshes during env renders (code above), then re-render. Verified to restore exact agreement (ratio 1.000, 0.3 % spread). | E6 `sphere_white_box_hidesec` |
# | 3 | **Data bug:** `env_i.exr` is not HDR — BlenderProc's `render()` returned the 8-bit PNG, so EXR/PNG/`_srgb.png` all carry uint8-quantized, [0,1]-clipped data. Fix with `set_output_format("OPEN_EXR")`. | E3 (round-quantizing the EXR changes nothing) |
# | 4 | **Numerics refuted:** `shade_ct_sh` float32 vs float64 differ by ~2e-7. (`shade_ct_env` in float32 does have a real instability around roughness 0.05–0.1, up to 8e-2 max error — worth clamping/fixing if you ever run ct_env in float32, but it vanishes in float64 and is unrelated to the Blender gap.) | E3 |
# | 5 | Low roughness is *not* where the model breaks (relative residual 0.70 vs 0.73 above/below r=0.15). Metallic pixels are the outlier (relative residual ~4.9): with the lighting bug, glossy env response is heavily suppressed. Expect this to largely disappear after the re-render. | E2 |
# | 6 | Decomposition behaviour is explained: the optimizer reaches the irreducible model-gap floor (E4: 0.023 vs 0.012 recon RMSE with GT intrinsics) by corrupting intrinsics and lighting jointly — hence roughness stuck at ~0.27 RMSE and albedo scale drifting (0.48 in run B). Freezing the nominal 2×GT-SH lighting (run C) makes it *worse* because the delivered lighting differs strongly from the nominal one — consistent with finding #1. | E4, E5 |
# | 7 | Minor pipeline notes: `tr_albedo="sigmoid"` is a silent no-op (`_fwd_albedo` only implements "log"); the rectified env PNG has ~14–35 % more irradiance than the signed SH it came from (rectification `max(SH,0)`), so even after the fix, prefer `ct_env` with the actual PNG (or signed-SH-consistent env maps) over `ct_sh` when decomposing Blender-rendered data; the linear `env_i.png` variant additionally truncates (not rounds) to 8 bits. | code reading, E1 |
#
# **Recommended actions**
# 1. ~~Patch `render_front3d_multipass.py` (visibility fix + `set_output_format("OPEN_EXR")`) and re-render the env dataset.~~ **Done — validated in E7.**
# 2. ~~Re-run the E1 forward-consistency check on the new data~~ **Done (E7): scale 1.0005.** Re-run the full-length decompositions on the fixed dataset.
# 3. Optionally fix `_fwd_albedo` sigmoid and the `shade_ct_env` float32 instability.
#
# ### Post-fix validation (E7, 2026-07-03)
#
# Both fixes were applied to `render_front3d_multipass.py` and the 128 env lights of scene
# `00004f89` / view 1 were re-rendered (same camera + env maps via `accepted_setup.json` replay;
# materials re-randomized, GT maps re-captured; old data in `output/backup 260703`):
#
# - forward model (GT intrinsics + Blender's exact env input) vs the fixed renders:
#   **LS scale 1.0005 ± 0.027** (was 0.52 ± 0.08) — the energy deficit is gone;
# - dielectric relative residual 0.70 → **0.087**; the remaining ~5% structural residual is the
#   genuine BSDF/geometry mismatch (Principled vs CT approximation, cc-texture normal maps,
#   proxy view directions);
# - `env_i.exr` is now true float HDR (off-grid values, >1 pixels preserved);
# - the 200-iter decomposition on the fixed data behaves like the CT control: albedo scale
#   **1.49** (control 1.51; on the buggy data it collapsed to 0.48), final data loss consistent
#   with the higher image brightness, materials still converging at 200 iters (as in the control).
#
# Next: re-run the full-length decompositions (`3dfront_ct.ipynb` cells, 128 images / 600–1000
# iters) on the re-rendered dataset; rebuild `results/3dfront-dataset-env*` first since the fixed
# data replaced `E:D-Front\output04f89...`.
