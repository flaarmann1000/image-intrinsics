# %%
from PIL import Image

def invert_green_channel(input_path: str, output_path: str) -> None:
    img = Image.open(input_path).convert("RGB")
    pixels = img.load()

    for y in range(img.height):
        for x in range(img.width):
            r, g, b = pixels[x, y]
            pixels[x, y] = (int(r* 0.5 + 0.5), int(g* 0.5 + 0.5), int(b* 0.5 + 0.5))

    img.save(output_path)

invert_green_channel(r"blender\blender_4_1_splash\normal_corr.exr", r"blender\blender_4_1_splash\normal_conv.png")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[1], line 14
#      10             pixels[x, y] = (int(r* 0.5 + 0.5), int(g* 0.5 + 0.5), int(b* 0.5 + 0.5))
#      12     img.save(output_path)
# ---> 14 invert_green_channel(r"blender\blender_4_1_splash\normal_corr.exr", r"blender\blender_4_1_splash\normal_conv.png")
#
# Cell In[1], line 4, in invert_green_channel(input_path, output_path)
#       3 def invert_green_channel(input_path: str, output_path: str) -> None:
# ----> 4     img = Image.open(input_path).convert("RGB")
#       5     pixels = img.load()
#       7     for y in range(img.height):
#
# File c:\Users\felix\miniconda3\Lib\site-packages\PIL\Image.py:3572, in open(fp, mode, formats)
#    3570     warnings.warn(message)
#    3571 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3572 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file 'blender\\blender_4_1_splash\\normal_corr.exr'

# %%
import os
import numpy as np
os.environ["OPENCV_IO_ENABLE_OPENEXR"] = "1"

import imageio.v3 as iio
# img = iio.imread(r"blender\blender_4_1_splash\normal_corr.exr")
img = iio.imread(r"blender\blender_4_1_splash\normal_corr.exr")
# img_uint8 = (img*255).astype(np.uint8)
# iio.imwrite(r"blender\blender_4_1_splash\normal_corr.png", img_uint8)

# %%
img_corr = img.copy()
img_corr[img > 1] = 1

# %%
img_cv2 = img_cv2.clip(0,1)
img_cv2.shape
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(img_cv2, vmin=0, vmax=1)

# plt.hist(img.flatten())

# %%
import cv2

img_cv2 = cv2.imread(r"blender\blender_4_1_splash\normal_corr.exr", cv2.IMREAD_ANYCOLOR)
# Out:
# (1080, 1920, 3)
